# %% [markdown]
# - Error handling is started from class_11.ipynb
# # Error Handling

# %% [markdown]
# ## Example: 1

# %%
print("logic1")
print("logic2")

l1: list[int] = [1,2,3]

try:
    print(7/2)
    print(l1[1]) 
    print("xyz") 
    open("abc.txt") # ERROR


except (ZeroDivisionError):
    print("Zero Division Error!")

except (IndexError):
    print("Index Error!")

except (NameError):
    print("Name Error!")

except: # It will work on all errors
    print("Something Went Wrong")


print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 3.5
# 2
# xyz
# Something Went Wrong
# logic4
# logic5

# %% [markdown]
# ### Error

# %%
print("logic1")
print("logic2")

l1: list[int] = [1,2,3]

try:
    print(7/2)
    print(l1[1]) 
    print(xyz) # ERROR

except (ZeroDivisionError):
    print("Zero Division Error!")

except (IndexError):
    print("Index Error!")

except (NameError):
    print("Name Error!")


print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 3.5
# 2
# Name Error!
# logic4
# logic5

# %% [markdown]
# ## Dynamic Error Handling

# %%
try:
    print(age)
    print(1/0)
except Exception as e:
    print(f"something is wrong!\n{e}")
# Out:
# something is wrong!
# division by zero

# %% [markdown]
# ## ERROR GENERATION

# %% [markdown]
# ### Example 2

# %%
class StudentCard():
    def __init__(self, roll_no: int, name: str, age: int) -> None:
        if age < 18 or age > 60:
            raise StudentAgeError("You are not eligible for this program!")
        self.roll_no = roll_no
        self.name = name
        self.age = age

# Error Generation
class StudentAgeError(Exception):   # Custom Error Class
    pass

student1 = StudentCard(12,"Saboor",21)
print(student1.age , student1.name , student1.age)
# Out:
# 21 Saboor 21

# %%
student1 = StudentCard(12,"Saboor",61)
print(student1.age , student1.name , student1.age) # now it will gave the Custom Error because of age
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# d:\Studies\Web3&Metaverse\Generative AI\Python\Class\class_12(Error_and_File_handling).ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> student1 = StudentCard(12,"Saboor",61)
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> print(student1.age , student1.name , student1.age)
#
# d:\Studies\Web3&Metaverse\Generative AI\Python\Class\class_12(Error_and_File_handling).ipynb Cell 12 line 4
# ...

# %% [markdown]
# # File Handling
#
# <img src="https://net-informations.com/python/file/img/modes.png">

# %% [markdown]
# ## Open Function

# %%
open("./abc.txt")
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='cp1252'>

# %%
data = open("./abc.txt")
data
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='cp1252'>

# %%
[i for i in dir(data) if "__" and "_" not in i]
# Out:
# ['buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'writelines']

# %%
print(type(data))
# Out:
# <class '_io.TextIOWrapper'>

# %% [markdown]
# ## Static Typing for File Variable

# %%
from typing import TextIO

data: TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())
# Out:
# line1
# line2

# %%
from typing import TextIO

data: TextIO = open("./abc.txt") # connectivity with abc.txt file
print(data.read())

data.close()    # Close connectivity

# %% [markdown]
# ### using With block

# %%
with open("./abc.txt") as file: # type: TextIO
    print(type(file))
    print(file.read())

print("We are out of \"with Block\". now we dont have access to the file")
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2
# We are out of "with Block". now we dont have access to the file

# %% [markdown]
# ### Readline and Readlines

# %% [markdown]
# #### Readline

# %%
with open("./abc.txt") as file: # type: TextIO
    print(type(file))
    print(file.readline())  # read only one line at a time
    print(file.readline())  # read only one line at a time
    # It Works like a Generative Function
# Out:
# <class '_io.TextIOWrapper'>
# line1
#
# line2

# %%
with open("./abc.txt") as file:  # type: TextIO
    print(type(file))
    print(file.readline(), end="")  # will escape the spaces
    print(file.readline(), end="")  
    # It Works like a Generative Function
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2

# %% [markdown]
# #### Readlines

# %%
with open("./abc.txt") as file: # type: TextIO
    print(type(file))
    print(file.readlines()) # it ill return a list so we can apply list methods
# Out:
# <class '_io.TextIOWrapper'>
# ['line1\n', 'line2']

# %%
with open("./abc.txt") as file: # type: TextIO
    print(type(file))
    print(file.readlines()[:3]) # it ill return a list so we can apply list methods
# Out:
# <class '_io.TextIOWrapper'>
# ['line1\n', 'line2']

# %% [markdown]
# ## Read and Write

# %%
with open("./abc.txt") as file: # type: TextIO
    print(file.read())
    file.write("Pakistan Zindabad")
# Out:
# line1
# line2
# line3
# line4
# line5
# line6
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# d:\Studies\Web3&Metaverse\Generative AI\Python\Class\class_12(Error_and_File_handling).ipynb Cell 31 line 3
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt") as file: # type: TextIO
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
# ----> <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a>     file.write("Pakistan Zindabad")
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt","w") as file: # type: TextIO
    print(file.read())
    file.write("Pakistan Zindabad")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# d:\Studies\Web3&Metaverse\Generative AI\Python\Class\class_12(Error_and_File_handling).ipynb Cell 32 line 2
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc.txt","w") as file: # type: TextIO
# ----> <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a>     print(file.read())
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a>     file.write("Pakistan Zindabad")
#
# UnsupportedOperation: not readable

# %%
with open("./abc-1.txt","w") as file: # type: TextIO
    file.write("Pakistan Zindabad")
    # it will clear all the code in abc-1.txt and write the above text we provided in .write function

# %%
with open("./abc-1.txt", "r+") as file:  # type: TextIO
    print(file.read())
    file.write("We love our country")
    # cursor will move to the last character of the file then write the sentence
# Out:
# Pakistan Zindabad

# %% [markdown]
# ### Showing the result after Writing

# %%
with open("./abc-1.txt", "r+") as file:  # type: TextIO
    print("Before: ",file.read())
    file.write("We love our country!")
    print("After: ",file.read())
# Out:
# Before:  Pakistan Zindabad
# After:

# %%
with open("./abc-1.txt", "r+") as file:  # type: TextIO
    print("Before: ",file.read())

    file.write("\tWe love our country!")
    file.seek(0) # it will move the cursor to the start

    print("After: ",file.read())
# Out:
# Before:  Pakistan Zindabad
# After:  Pakistan Zindabad	We love our country!

# %% [markdown]
# ### Mode Change
#
# <table class="s-table">
# <thead>
# <tr>
# <th style="text-align: center;">Mode</th>
# <th style="text-align: center;">r</th>
# <th style="text-align: center;">r+</th>
# <th style="text-align: center;">w</th>
# <th style="text-align: center;">w+</th>
# <th style="text-align: center;">a</th>
# <th style="text-align: center;">a+</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align: center;">Read</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Write</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Create</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# <tr>
# <td style="text-align: center;">Cover</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the beginning</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">Point in the end</td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;"></td>
# <td style="text-align: center;">+</td>
# <td style="text-align: center;">+</td>
# </tr>
# </tbody>
# </table>

# %%
with open("./abc2.txt", "w") as file:
    file.write("Pakistan")

# if file exist then it will overwrite the text
# if file does'nt exist then it will create new file

# %%
with open("./abc2.txt", "a") as file:   # "a" is called append mode
    file.write("Pakistan")

# if file does'nt exist then it will create new file
# add content in last line

# %%
with open("./abc2.txt", "x") as file:   # "x" will always create a new file
    file.write("X mode")

# if file exist then it will gave error
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# d:\Studies\Web3&Metaverse\Generative AI\Python\Class\class_12(Error_and_File_handling).ipynb Cell 41 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X60sZmlsZQ%3D%3D?line=0'>1</a> with open("./abc2.txt", "x") as file:
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X60sZmlsZQ%3D%3D?line=1'>2</a>     file.write("X mode ")
#       <a href='vscode-notebook-cell:/d%3A/Studies/Web3%26Metaverse/Generative%20AI/Python/Class/class_12%28Error_and_File_handling%29.ipynb#X60sZmlsZQ%3D%3D?line=3'>4</a> # if file exist then it will overwrite the text
# ...

# %%
with open("./abc2.txt", "rb") as file:   # "rb" -> read binary
    file.read()

# if file exist then it will gave error

# %% [markdown]
# ## Read some real-world data files
# * image
# * csv
# * audio

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv("./data.csv")

df
# Out:
#    id    name education
# 0   1  saboor      BSCS
# 1   2    sadd      BSCE

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ----------------------- --------------- 92.2/155.5 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------  153.6/155.5 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 155.5/155.5 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.6 MB 1.7 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/7.6 MB 1.8 MB/s eta 0:00:05
#    ---------------------------------------- 0.1/7.6 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.2/7.6 MB 1.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.6 MB 1.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.6 MB 1.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/7.6 MB 1.6 MB/s eta 0:00:05
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpimg

img = mpimg.imread("picture.jpg")   # convert into numpy array

plt.imshow(img)

# %% [markdown]
# ### Audio File

# %%
from pydub import AudioSegment

audio = AudioSegment.from_file("file.mp3")
print("Channels:", audio.channels)
print("Sample Width:", audio.sample_width)
print("Frame Rate:", audio.frame_rate)
print("Frame Width:", audio.frame_width)
print("Length (ms):", len(audio))
print("Frame Count:", audio.frame_count())
