# %% [markdown]
# ### This is the First Class of Python!
#
# #### Note: Create and Set Python Enviroment Before Running your Code

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# To Install all the libraries written in requirement files then Use the Following Command
#
# * Note: We Use " ! " to run ternimal command in the code.

# %%
! pip install -r requirement.txt
# Out:
# ...
#    ---------------------------------------- 0.0/9.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.0 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/9.0 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/9.0 MB 3.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/9.0 MB 3.7 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/9.0 MB 3.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/9.0 MB 3.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.0 MB 3.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.0 MB 3.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.0 MB 4.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/9.0 MB 3.5 MB/s eta 0:00:03
#    -------- ------------------------------- 1.8/9.0 MB 3.6 MB/s eta 0:00:02
# ...

# %% [markdown]
# - Old Syntax and Methods of Python

# %%
# Old Syntax of Python
name = "Saboor Hussain"
name = 100
print(name) # print
print(type(name)) # type
print(id(name)) # physical address
# Out:
# 100
# <class 'int'>
# 140728343715720
